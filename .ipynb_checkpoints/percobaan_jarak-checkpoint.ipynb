# %%
import numpy as np
import pandas as pd

# %%
dataFace = pd.DataFrame([[0,40,15,60,"dilan"],
                     [30,30,45,50,"doni"],
                     [40,60,55,75,"jojo"],
                     [55,40,70,50,"putri"],
                     [73,45,88,60,"geri"],
                     [50,80,65,100,"toni"],
                     [70,85,85,105,"rina"],
                    [20,25,33,40,'dimas'],
                    [55,105,65,120,'ratu']], columns=("kiri","atas","kanan","bawah","nama"))

# %%
dataFace = pd.DataFrame([[0,40,0,20,"dilan"],
                     [30,30,15,20,"doni"],
                     [40,60,15,15,"jojo"],
                     [55,40,15,10,"putri"],
                     [73,45,15,15,"geri"],
                     [50,80,15,20,"toni"],
                     [70,85,15,20,"rina"],
                    [20,25,13,15,'dimas'],
                    [55,105,10,15,'ratu']], columns=("kiri","atas","kanan","bawah","nama"))

dataFace['kanan'] = dataFace['kiri']+ dataFace['kanan']
dataFace['bawah'] = dataFace['atas']+ dataFace['bawah']

# %%
#dataFace.iloc[0].values
#print(dataFace.where(dataFace['nama'] != 'joni').values)
#print(dir(dataFace))
#print(dataFace.index)
data = [55,40,70,50,"putri"]
o = []
print(dataFace[dataFace['nama'] != data[4]].values)
for b in dataFace[dataFace['nama'] != data[4]].values:
    print(b)
    #if ((b[0] < data[2]+10 and b[0] > data[2]) or (b[2] < data[0]+10 and b[2] > data[0])) and (b[1] <= data[3]+5 and b[1] >= data[1]+5):
    if ((data[2]+10 >= b[0] and data[2] <= b[2]+10) or (data[0]-10 <= b[2] and data[0] >= b[0]+10)) and ((data[1] < b[3] and data[1] >= b[1]+5) or (data[3] <= b[3]+5 and data[3] > b[1])):
        o.append(dataFace[dataFace['nama'] == b[4]].nama.values)
    #print(data[4])
    print('=============\n')
print(o)
#d = dataFace[dataFace.kiri == 55]
#print(d)
#print(dir(dataFace))
# Out:
# [[0 40 15 60 'dilan']
#  [30 30 45 50 'doni']
#  [40 60 55 75 'jojo']
#  [73 45 88 60 'geri']
#  [50 80 65 100 'toni']
#  [70 85 85 105 'rina']
#  [20 25 33 40 'dimas']
#  [55 105 65 120 'ratu']]
# [0 40 15 60 'dilan']
# ...
#
# [30 30 45 50 'doni']
# ...
#
# [40 60 55 75 'jojo']
# ...
#
# [73 45 88 60 'geri']
# ...
#
# [50 80 65 100 'toni']
# ...
#
# [70 85 85 105 'rina']
# ...
#
# [20 25 33 40 'dimas']
# ...
#
# [55 105 65 120 'ratu']
# ...
#
# [array(['doni'], dtype=object), array(['geri'], dtype=object)]

# %%
#dataFace.iloc[0].values
#print(dataFace.where(dataFace['nama'] != 'joni').values)
#print(dir(dataFace))
#print(dataFace.index)
for i, data in enumerate(dataFace.values):
    for b in dataFace[dataFace['nama'] != data[4]].values:
        #print(b)
        #if ((b[0] < data[2]+10 and b[0] > data[2]) or (b[2] < data[0]+10 and b[2] > data[0])) and (b[1] <= data[3]+5 and b[1] >= data[1]+5):
        if ((data[2]+10 >= b[0] and data[2] <= b[2]+10) or (data[0]-10 <= b[2] and data[0] >= b[0]+10)) and ((data[1] < b[3] and data[1] >= b[1]+5) or (data[3] <= b[3]+5 and data[3] > b[1])):
            print(dataFace[dataFace['nama'] == b[4]].nama.values)
    print(data[4])
    print('=============\n')

d = dataFace[dataFace.kiri == 55]
print(d)dilan
#print(dir(dataFace))
# Out:
# dilan
# ...
#
# ['putri']
# ['dimas']
# doni
# ...
#
# jojo
# ...
#
# ['doni']
# ['geri']
# putri
# ...
#
# ['putri']
# geri
# ...
#
# ['rina']
# toni
# ...
#
# ['toni']
# rina
# ...
#
# ['doni']
# dimas
# ...
#
# ratu
# ...
#
#    kiri  atas  kanan  bawah   nama
# 3    55    40     70     50  putri
# 8    55   105     65    120   ratu
